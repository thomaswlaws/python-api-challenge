# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_city = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
records_counter = 0
set_count = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be"
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if records_counter < 50:
        records_counter += 1
    else:
        set_count += 1
        records_counter = 0

    print('Processing record {} of set {} | {}'.format(records_counter, set_count, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("Could not find city!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# d not find city!
# Processing record 6 of set 9 | ejutla de crespo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 7 of set 9 | saint marys
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 8 of set 9 | kalianget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 9 of set 9 | la louviere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 10 of set 9 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 11 of set 9 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 12 of set 9 | lakhdenpokhya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 13 of set 9 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 14 of set 9 | krasnyye chetai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 15 of set 9 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 16 of set 9 | kamariotissa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 17 of set 9 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 18 of set 9 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 19 of set 9 | jiutai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 20 of set 9 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 21 of set 9 | panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 22 of set 9 | ercis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 23 of set 9 | ofunato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 24 of set 9 | yermakovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 25 of set 9 | sarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 26 of set 9 | boddam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 27 of set 9 | bani walid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 28 of set 9 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 29 of set 9 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 30 of set 9 | trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 31 of set 9 | katsina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 32 of set 9 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 33 of set 9 | aldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 34 of set 9 | wabana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 35 of set 9 | kyshtym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 36 of set 9 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 37 of set 9 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 38 of set 9 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 39 of set 9 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 40 of set 9 | gien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 41 of set 9 | krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 42 of set 9 | sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 43 of set 9 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 44 of set 9 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 45 of set 9 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 46 of set 9 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 47 of set 9 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 48 of set 9 | port pirie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 49 of set 9 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 50 of set 9 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Could not find city!
# Processing record 0 of set 10 | minsk mazowiecki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 1 of set 10 | suriapet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 2 of set 10 | rosendahl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 3 of set 10 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 4 of set 10 | patacamaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 5 of set 10 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 6 of set 10 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 7 of set 10 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 8 of set 10 | santo tomas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 9 of set 10 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 10 of set 10 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 11 of set 10 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Could not find city!
# Processing record 12 of set 10 | tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 13 of set 10 | altoona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 14 of set 10 | vadso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 15 of set 10 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 16 of set 10 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 17 of set 10 | merano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 18 of set 10 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 19 of set 10 | hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 20 of set 10 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 21 of set 10 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 22 of set 10 | jatai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 23 of set 10 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 24 of set 10 | rafai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 25 of set 10 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 26 of set 10 | thessalon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 27 of set 10 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 28 of set 10 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 29 of set 10 | jahazpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 30 of set 10 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 31 of set 10 | matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 32 of set 10 | onokhoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 33 of set 10 | vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 34 of set 10 | dingzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 35 of set 10 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 36 of set 10 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 37 of set 10 | foix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 38 of set 10 | wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 39 of set 10 | maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 40 of set 10 | la orilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 41 of set 10 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 42 of set 10 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 43 of set 10 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 44 of set 10 | south berwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 45 of set 10 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 46 of set 10 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 47 of set 10 | tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 48 of set 10 | aquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 49 of set 10 | arinos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 50 of set 10 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 0 of set 11 | moba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 1 of set 11 | kharitonovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 2 of set 11 | abdanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 3 of set 11 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 4 of set 11 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 5 of set 11 | shymkent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 6 of set 11 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 7 of set 11 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 8 of set 11 | karasburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 9 of set 11 | amos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 10 of set 11 | zavetnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 11 of set 11 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 12 of set 11 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 13 of set 11 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 14 of set 11 | jiangdu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 15 of set 11 | zdvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 16 of set 11 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 17 of set 11 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 18 of set 11 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 19 of set 11 | djibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 20 of set 11 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 21 of set 11 | skoghall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 22 of set 11 | berezovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 23 of set 11 | concepcion del oro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 24 of set 11 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 25 of set 11 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 26 of set 11 | camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 27 of set 11 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 28 of set 11 | malatya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 29 of set 11 | mpika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 30 of set 11 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 31 of set 11 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 32 of set 11 | sao paulo de olivenca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 33 of set 11 | manacor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 34 of set 11 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 35 of set 11 | monasterevan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Could not find city!
# Processing record 36 of set 11 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 37 of set 11 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 38 of set 11 | chulym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 39 of set 11 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 40 of set 11 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 41 of set 11 | tarrafal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# Processing record 42 of set 11 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32edf3f260d3729a4154009b3009b5be
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          566
# Cloudiness    566
# Country       566
# Date          566
# Humidity      566
# Temp          566
# Lat           566
# Lng           566
# Wind Speed    566
# dtype: int64

# %%
weather_data['Temp'] = weather_data['Temp'].replace('', np.nan)
weather_data = weather_data.dropna()
weather_data["Date"]= pd.to_datetime(weather_data['Date'], unit='s', utc=True)
weather_data.head()
# Out:
#            City  Cloudiness Country                      Date  Humidity  \
# 0         vigia          90      BR 2020-04-18 01:58:13+00:00        94
# 1  punta arenas          14      CL 2020-04-18 01:55:10+00:00        66
# 2        kodiak          90      US 2020-04-18 01:58:13+00:00        76
# 3      chumikan          97      RU 2020-04-18 01:58:13+00:00        85
# 4       rikitea           1      PF 2020-04-18 01:54:40+00:00        63
#
#     Temp    Lat     Lng  Wind Speed
# 0  77.00  -0.86  -48.14        1.12
# 1  48.20 -53.15  -70.92       11.41
# 2  51.80  57.79 -152.41       10.29
# 3  29.53  54.72  135.31        5.61
# 4  77.36 -23.12 -134.97        1.99

# %%
 

weather_data.to_csv("output_data/cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (04/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (04/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/Fig2.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (04/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/fig3.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (04/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("output_data/fig4.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
# Create Northern and Southern Hemisphere DataFrames
north_df = weather_data.loc[pd.to_numeric(weather_data["Lat"]).astype(float) > 0, :]
south_df = weather_data.loc[pd.to_numeric(weather_data["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Northern Hemisphere - Temperature vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -1.0x + 93.47
# The r-squared is: -0.891532921506678
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.title('Southern Hemisphere - Temperature vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.53x + 82.22
# The r-squared is: 0.6328604322991572
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.29x + 57.35
# The r-squared is: 0.25873122827746986
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.26x + 76.12
# The r-squared is: 0.19813143558092322
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%) ')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.4x + 39.4
# The r-squared is: 0.19978885529758245
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%) ')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.55x + 66.49
# The r-squared is: 0.21635609609941953
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.05x + 6.76
# The r-squared is: 0.15900843917594695
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.13x + 3.71
# The r-squared is: -0.427263146749682
# The regression does not display much of a correlation between the data sets.
